# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
melb2 = pd.read_csv("Melbourne01.csv",low_memory=False,on_bad_lines="skip")

# %%
melb2.head(30)
# Out:
#     2011   1   1.1    0     4   24.8   0.0   14.0    51    SE    11    13  \
# 0   2011   1   1.0  0.0   4.0   24.8   0.0   14.0  51.0    SE  11.0  13.0
# 1   2011   1   1.0  0.0  14.0   24.8   0.0   13.3  48.0    SE  11.0  11.0
# 2   2011   1   1.0  0.0  14.0   24.8   0.0   13.3  48.0    SE  11.0  11.0
# 3   2011   1   1.0  0.0  24.0   24.9   0.0   13.3  48.0    SE  11.0  13.0
# 4   2011   1   1.0  0.0  24.0   24.9   0.0   13.3  48.0    SE  11.0  13.0
# 5   2011   1   1.0  0.0  34.0   24.7   0.0   13.4  49.0    SE  11.0  11.0
# 6   2011   1   1.0  0.0  34.0   24.7   0.0   13.4  49.0    SE  11.0  11.0
# 7   2011   1   1.0  0.0  34.0   24.7   0.0   13.4  49.0    SE  11.0  11.0
# 8   2011   1   1.0  0.0  44.0   24.1   0.0   13.3  51.0   ESE   9.0   9.0
# 9   2011   1   1.0  0.0  54.0   24.3   0.0   13.3  50.0    NE   9.0   9.0
# 10  2011   1   1.0  0.0  54.0   24.3   0.0   13.3  50.0    NE   9.0   9.0
# 11  2011   1   1.0  1.0   4.0   24.1   0.0   13.3  51.0   NNE   7.0   7.0
# ...

# %%
melb.head(10)
# Out:
#    Year Month  Day  Hour   Min  Air Temp (degrees C)  \
# 0  2011     1  1.0   0.0   4.0                  24.8
# 1  2011     1  1.0   0.0  14.0                  24.8
# 2  2011     1  1.0   0.0  24.0                  24.9
# 3  2011     1  1.0   0.0  34.0                  24.7
# 4  2011     1  1.0   0.0  44.0                  24.1
# 5  2011     1  1.0   0.0  54.0                  24.3
# 6  2011     1  1.0   1.0   4.0                  24.1
# 7  2011     1  1.0   1.0  14.0                  23.5
# 8  2011     1  1.0   1.0  24.0                  23.3
# 9  2011     1  1.0   1.0  34.0                  23.6
#
#    Apparent Temp (degrees C)  Dew Pt Temp (degrees C)  Humidity (%)  \
# 0                        0.0                     14.0          51.0
# 1                        0.0                     13.3          48.0
# 2                        0.0                     13.3          48.0
# 3                        0.0                     13.4          49.0
# ...

# %%
melb.tail(20)
# Out:
#         Year Month  Day  Hour   Min  Air Temp (degrees C)  \
# 505335  2022     3  8.0  12.0  50.0                  19.4
# 505336  2022     3  8.0  13.0  20.0                  19.2
# 505337  2022     3  8.0  13.0  30.0                  19.2
# 505338  2022     3  8.0  13.0  40.0                  19.4
# 505339  2022     3  8.0  13.0  50.0                  19.8
# 505340  2022     3  8.0  14.0   0.0                  19.2
# 505341  2022     3  8.0  14.0  10.0                  19.3
# 505342  2022     3  8.0  14.0  20.0                  19.3
# 505343  2022     3  8.0  14.0  30.0                  19.1
# 505344  2022     3  8.0  14.0  40.0                  19.1
# 505345  2022     3  8.0  14.0  50.0                  19.2
# 505346  2022     3  8.0  15.0   0.0                  18.9
# 505347  2022     3  8.0  15.0  10.0                  18.9
# 505348  2022     3  8.0  15.0  20.0                  18.7
# 505349  2022     3  8.0  15.0  30.0                  18.7
# ...

# %%
melb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505355 entries, 0 to 505354
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Year                                  505222 non-null  object
#  1   Month                                 504739 non-null  object
#  2   Day                                   504723 non-null  float64
#  3   Hour                                  504723 non-null  float64
#  4   Min                                   504723 non-null  float64
#  5   Air Temp (degrees C)                  504723 non-null  float64
#  6   Apparent Temp (degrees C)             504723 non-null  float64
#  7   Dew Pt Temp (degrees C)               504723 non-null  float64
#  8   Humidity (%)                          504723 non-null  float64
#  9   Wind Direction                        504723 non-null  object
# ...

# %%
melb.describe()
# Out:
#                  Day           Hour            Min  Air Temp (degrees C)  \
# count  504723.000000  504723.000000  504723.000000         504723.000000
# mean       15.740000      11.443412      26.288140             15.972608
# std         8.818064       6.883219      17.197089              5.624138
# min         1.000000       0.000000       0.000000              0.000000
# 25%         8.000000       5.000000      10.000000             12.100000
# 50%        16.000000      11.000000      25.000000             15.300000
# 75%        23.000000      17.000000      40.000000             19.200000
# max        31.000000      23.000000      59.000000             43.500000
#
#        Apparent Temp (degrees C)  Dew Pt Temp (degrees C)   Humidity (%)  \
# count              504723.000000            504723.000000  504723.000000
# mean                   12.087050                 9.055060      66.386806
# std                     7.203826                 4.086159      17.756705
# ...

# %%
melb.shape
# Out:
# (505355, 18)

# %%
adel = pd.read_csv("Adelaide01.csv", low_memory=False)

# %%
adel.head(10)
# Out:
#    2015   08   15   09   00   12.2   11.2    11    92     N     9    13  \
# 0  2015    8   15    9   30   12.9   11.8  10.6  86.0     N  11.0  13.0
# 1  2015    8   15   10    0   12.9   11.8  10.8  87.0     N  11.0  17.0
# 2  2015    8   15   10   30   13.6   12.5  10.7  82.0    NW  15.0  17.0
# 3  2015    8   15   11    0   13.5   12.3  10.2  80.0    NW  13.0  17.0
# 4  2015    8   15   11   30   14.1   12.9  10.2  77.0   WNW  13.0  15.0
# 5  2015    8   15   12    0   14.2   12.8   9.5  73.0   WNW  15.0  19.0
# 6  2015    8   15   12   30   13.8   12.5   9.9  77.0   WNW  15.0  19.0
# 7  2015    8   15   13    0   13.5   12.1  11.0  85.0     W  17.0  19.0
# 8  2015    8   15   13   30   13.3   12.1  10.2  81.0     W  13.0  17.0
# 9  2015    8   15   14    0   13.3   11.8  10.4  82.0   WSW  13.0  17.0
#
#     1032.7  1.4
# 0   1032.9    0
# 1   1032.9    0
# 2   1032.9    0
# 3   1032.7    0
# 4   1032.6    0
# 5   1032.5    0
# 6   1032.2    0
# 7   1031.7    0
# 8   1031.4    0
# ...

# %%
melb.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Min', 'Air Temp (degrees C)',
#        'Apparent Temp (degrees C)', 'Dew Pt Temp (degrees C)', 'Humidity (%)',
#        'Wind Direction', 'Wind Speed (km/h)', 'Wind Gust  (km/h)',
#        'MSLP (hPa)', 'Rainfall since 9 am (mm)', 'gamma',
#        'Calculated Dew Pt Temp (degrees C)', 'E (hPa)',
#        'Calculated Apparent Temp (degrees C)'],
#       dtype='object')

# %%
melb2.columns = ['Year', 'Month', 'Day', 'Hour', 'Min', 'Air Temp (degrees C)',
       'Apparent Temp (degrees C)', 'Dew Pt Temp (degrees C)', 'Humidity (%)',
       'Wind Direction', 'Wind Speed (km/h)', 'Wind Gust  (km/h)',
       'MSLP (hPa)', 'Rainfall since 9 am (mm)']

# %%
melb2.head(20)
# Out:
#     Year Month  Day  Hour   Min  Air Temp (degrees C)  \
# 0   2011     1  1.0   0.0   4.0                  24.8
# 1   2011     1  1.0   0.0  14.0                  24.8
# 2   2011     1  1.0   0.0  14.0                  24.8
# 3   2011     1  1.0   0.0  24.0                  24.9
# 4   2011     1  1.0   0.0  24.0                  24.9
# 5   2011     1  1.0   0.0  34.0                  24.7
# 6   2011     1  1.0   0.0  34.0                  24.7
# 7   2011     1  1.0   0.0  34.0                  24.7
# 8   2011     1  1.0   0.0  44.0                  24.1
# 9   2011     1  1.0   0.0  54.0                  24.3
# 10  2011     1  1.0   0.0  54.0                  24.3
# 11  2011     1  1.0   1.0   4.0                  24.1
# 12  2011     1  1.0   1.0   4.0                  24.1
# 13  2011     1  1.0   1.0  14.0                  23.5
# 14  2011     1  1.0   1.0  14.0                  23.5
# 15  2011     1  1.0   1.0  24.0                  23.3
# ...

# %%
melb2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113151 entries, 0 to 1113150
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Year                       1113151 non-null  object
#  1   Month                      1112535 non-null  object
#  2   Day                        1112519 non-null  float64
#  3   Hour                       1112519 non-null  float64
#  4   Min                        1112519 non-null  float64
#  5   Air Temp (degrees C)       1112519 non-null  float64
#  6   Apparent Temp (degrees C)  1112519 non-null  float64
#  7   Dew Pt Temp (degrees C)    1112519 non-null  float64
#  8   Humidity (%)               1112519 non-null  float64
#  9   Wind Direction             1112519 non-null  object
#  10  Wind Speed (km/h)          1112519 non-null  float64
#  11  Wind Gust  (km/h)          1112519 non-null  float64
# ...

# %%
# change the day, hour, min datatypes
# concatenate the time components together and put into datetime type
# add to new dataframe?

# start doing EDA
    # Add to the Github
